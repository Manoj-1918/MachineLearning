# %% [markdown]
# lets practice one more time

# %%
#import the necessary data
import pandas as pd
from ydata_profiling import ProfileReport

# %%
earthquake= pd.read_csv('all_month.csv')
print(earthquake.head())
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2025-12-11T02:44:15.295Z  62.841000 -148.271000  63.70  2.30      ml  45.0
# 1  2025-12-11T02:35:00.746Z  61.918000 -149.267000   2.60  2.00      ml  23.0
# 2  2025-12-11T02:21:24.210Z  34.200167 -116.790000   1.46  0.80      ml  29.0
# 3  2025-12-11T02:11:50.960Z  33.677167 -116.778500  17.80  0.98      ml  52.0
# 4  2025-12-11T01:58:23.900Z  18.014667  -66.807333  15.89  2.35      md  11.0
#
#      gap     dmin   rms  ...                   updated  \
# 0   40.0  0.10000  0.80  ...  2025-12-11T02:45:52.387Z
# 1   55.0  0.20000  0.90  ...  2025-12-11T02:37:16.578Z
# 2   49.0  0.12480  0.12  ...  2025-12-11T02:25:01.452Z
# 3   26.0  0.06663  0.15  ...  2025-12-11T02:22:28.550Z
# 4  154.0  0.04836  0.16  ...  2025-12-11T02:19:14.620Z
#
#                                  place        type horizontalError depthError  \
# 0        70 km SSE of Cantwell, Alaska  earthquake            0.00     2.9581
# ...

# %%
prof=ProfileReport(earthquake)
prof.to_file(output_file='EarthquakeDetails.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/22 [00:00<?, ?it/s]
# %|███▊                                                                               | 1/22 [00:00<00:14,  1.49it/s]
# %|███████▌                                                                           | 2/22 [00:00<00:06,  2.96it/s]
# %|███████████▎                                                                       | 3/22 [00:00<00:04,  4.16it/s]
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile = ProfileReport(earthquake, title="Profiling Report")

profile.to_file("your_report.json")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/22 [00:00<?, ?it/s]
# %|███▊                                                                               | 1/22 [00:00<00:20,  1.03it/s]
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
