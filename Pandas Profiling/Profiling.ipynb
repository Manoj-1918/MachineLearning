# %% [markdown]
# Import the necessary library

# %%
import pandas as pd
import seaborn as sns

# %%
tips= sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# we are going to do pandas profiling now

# %%
from pandas_profile import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from pandas_profile import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profile'

# %% [markdown]
# we have not installed it now , so install it first

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(tips)
profile.to_file(output_file="Tips_Data_Analysis.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
