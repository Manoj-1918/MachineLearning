# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('database.csv',usecols=['Date','Time','ID'])

# %%
df.sample(5)
# Out:
#              Date      Time          ID
# 13652  08/30/1997  03:28:35  USP00086VR
# 11821  02/28/1994  21:52:56  USP000693G
# 8240   11/01/1986  18:56:28  USP0002ZK4
# 18263  02/09/2007  02:22:55  USP000F4HN
# 6788   11/06/1983  21:09:45  USP0001ZM0

# %%
df.info()
df.iloc[2095:2097,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    23412 non-null  object
#  1   Time    23412 non-null  object
#  2   ID      23412 non-null  object
# dtypes: object(3)
# memory usage: 548.8+ KB
#             Date      Time            ID
# 2095  09/24/1971  01:10:02  ISCGEM780560
# 2096  09/24/1971  04:32:57  ISCGEM780563

# %%
#change object format to dateTime format
df['Date']=pd.to_datetime(df['Date'],format='mixed',utc=True)
df['Time']=pd.to_datetime(df['Time'],format='mixed').dt.time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 3
#       1 #change object format to dateTime format
#       2 df['Date']=pd.to_datetime(df['Date'],format='mixed',utc=True)
# ----> 3 df['Time']=pd.to_datetime(df['Time'],format='mixed').dt.time
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    23412 non-null  datetime64[ns, UTC]
#  1   Time    23412 non-null  object
#  2   ID      23412 non-null  object
#  3   year    23412 non-null  int32
# dtypes: datetime64[ns, UTC](1), int32(1), object(2)
# memory usage: 640.3+ KB

# %%
#extract the deatils seperately
year=df['Date'].dt.year
year.sample(5)
df['year']=df['Date'].dt.year

# %%
df.sample()

# %%
df['Month'] = df['Date'].dt.month

# %%
df.sample()

# %%
df['Month_name'] = df['Date'].dt.month_name()
df.sample()
