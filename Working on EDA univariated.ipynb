# %% [markdown]
# Working on EDA univariated

# %%
#import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import the data set needed to study on

# %%
titanic = pd.read_csv("train.csv")
iris=sns.load_dataset('iris')
tips=sns.load_dataset('tips')
flights=sns.load_dataset('flights')

# %%
#working with understanding data
tips.shape
# Out:
# (244, 7)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe()['tip']
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
tips.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# this shows that correlation finding can let us know which varibles are more related

# %%
#we will work on plotting the dataset for visulization to find inner insights

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
titanic['Pclass'].value_counts().plot(kind='pie',autopct='%.3f')
# Out:
# <Axes: ylabel='count'>

# %%
#for numneric data

# %%
plt.hist(titanic['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(titanic['Age'])
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_23432\3677708691.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(titanic['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(titanic['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.scatterplot(x=tips['total_bill'], y=tips['tip'])
sns.scatterplot(data=tips, x='total_bill', y='tip',hue='sex',style='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
dia=pd.read_csv('diabetes.csv')

# %%
dia.sample(8)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 330            8      118             72             19        0  23.1
# 626            0      125             68              0        0  24.7
# 623            0       94             70             27      115  43.5
# 156            2       99             52             15       94  24.6
# 624            2      108             64              0        0  30.8
# 398            3       82             70              0        0  21.1
# 555            7      124             70             33      215  25.5
# 619            0      119              0              0        0  32.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 330                     1.476   46        0
# 626                     0.206   21        0
# 623                     0.347   21        0
# 156                     0.637   21        0
# 624                     0.158   21        0
# 398                     0.389   25        0
# ...

# %%
dia.corr(numeric_only=True)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.scatterplot(data=dia,x='Age',y='Glucose')
# Out:
# <Axes: xlabel='Age', ylabel='Glucose'>

# %%
dia['Pregnancies'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.distplot(dia['Age'])
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_23432\4234560111.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dia['Age'])
# <Axes: xlabel='Age', ylabel='Density'>
